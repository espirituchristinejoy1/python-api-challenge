# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 567

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}appid={weather_api_key}&q={city}&units={units}"

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url)
        city_weather_json = city_weather.json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather_json["coord"]["lat"]
        city_lng = city_weather_json["coord"]["lon"]
        city_max_temp = city_weather_json["main"]["temp_max"]
        city_humidity = city_weather_json["main"]["humidity"]
        city_clouds = city_weather_json["clouds"]["all"]
        city_wind = city_weather_json["wind"]["speed"]
        city_country = city_weather_json["sys"]["country"]
        city_date = city_weather_json["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

    # pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | buala
# Processing Record 2 of Set 1 | choibalsan
# Processing Record 3 of Set 1 | blackmans bay
# Processing Record 4 of Set 1 | ribeira grande
# Processing Record 5 of Set 1 | kimbe
# Processing Record 6 of Set 1 | adamstown
# Processing Record 7 of Set 1 | carnarvon
# Processing Record 8 of Set 1 | qaqortoq
# Processing Record 9 of Set 1 | jianshui
# Processing Record 10 of Set 1 | isafjordur
# Processing Record 11 of Set 1 | utrik
# Processing Record 12 of Set 1 | hawera
# Processing Record 13 of Set 1 | howrah
# Processing Record 14 of Set 1 | waitangi
# Processing Record 15 of Set 1 | tiksi
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | stanley
# Processing Record 18 of Set 1 | invercargill
# Processing Record 19 of Set 1 | grytviken
# Processing Record 20 of Set 1 | la mira
# Processing Record 21 of Set 1 | port-aux-francais
# Processing Record 22 of Set 1 | taoudenni
# Processing Record 23 of Set 1 | enewetak
# Processing Record 24 of Set 1 | klyuchi
# Processing Record 25 of Set 1 | port mathurin
# Processing Record 26 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 27 of Set 1 | minas de marcona
# Processing Record 28 of Set 1 | mount pearl
# Processing Record 29 of Set 1 | kodiak
# Processing Record 30 of Set 1 | bredasdorp
# Processing Record 31 of Set 1 | aksu
# Processing Record 32 of Set 1 | camana
# Processing Record 33 of Set 1 | albany
# Processing Record 34 of Set 1 | ilulissat
# Processing Record 35 of Set 1 | iqaluit
# Processing Record 36 of Set 1 | puerto natales
# Processing Record 37 of Set 1 | constantia
# Processing Record 38 of Set 1 | tanjung pandan
# Processing Record 39 of Set 1 | nemuro
# Processing Record 40 of Set 1 | longyearbyen
# Processing Record 41 of Set 1 | puerto ayora
# Processing Record 42 of Set 1 | bartica
# Processing Record 43 of Set 1 | alice springs
# Processing Record 44 of Set 1 | waycross
# Processing Record 45 of Set 1 | maun
# Processing Record 46 of Set 1 | walvis bay
# Processing Record 47 of Set 1 | peace river
# Processing Record 48 of Set 1 | angra do heroismo
# Processing Record 49 of Set 1 | thompson
# Processing Record 50 of Set 1 | yellowknife
# Processing Record 0 of Set 2 | mana
# Processing Record 1 of Set 2 | fortuna
# Processing Record 2 of Set 2 | funafuti
# Processing Record 3 of Set 2 | west island
# Processing Record 4 of Set 2 | inhambane
# Processing Record 5 of Set 2 | punta arenas
# Processing Record 6 of Set 2 | ubud
# Processing Record 7 of Set 2 | tranovaho
# City not found. Skipping...
# Processing Record 8 of Set 2 | porto velho
# Processing Record 9 of Set 2 | usogorsk
# Processing Record 10 of Set 2 | ytyk-kyuyel'
# City not found. Skipping...
# Processing Record 11 of Set 2 | trindade
# Processing Record 12 of Set 2 | queenstown
# Processing Record 13 of Set 2 | puerto san carlos
# City not found. Skipping...
# Processing Record 14 of Set 2 | sinabang
# Processing Record 15 of Set 2 | port hedland
# Processing Record 16 of Set 2 | rukungiri
# Processing Record 17 of Set 2 | anadyr
# Processing Record 18 of Set 2 | nagqu
# Processing Record 19 of Set 2 | rabo de peixe
# Processing Record 20 of Set 2 | nova vicosa
# Processing Record 21 of Set 2 | kununurra
# Processing Record 22 of Set 2 | san antonio de pale
# Processing Record 23 of Set 2 | arno
# Processing Record 24 of Set 2 | 'ohonua
# City not found. Skipping...
# Processing Record 25 of Set 2 | papatowai
# Processing Record 26 of Set 2 | wailua homesteads
# Processing Record 27 of Set 2 | la palma
# Processing Record 28 of Set 2 | darwin
# Processing Record 29 of Set 2 | bilibino
# Processing Record 30 of Set 2 | tamiahua
# Processing Record 31 of Set 2 | bumba
# Processing Record 32 of Set 2 | hermanus
# Processing Record 33 of Set 2 | port elizabeth
# Processing Record 34 of Set 2 | bethel
# Processing Record 35 of Set 2 | atafu village
# Processing Record 36 of Set 2 | fale old settlement
# Processing Record 37 of Set 2 | lorengau
# Processing Record 38 of Set 2 | mejit
# Processing Record 39 of Set 2 | el haouaria
# Processing Record 40 of Set 2 | margaret river
# Processing Record 41 of Set 2 | avarua
# Processing Record 42 of Set 2 | jamestown
# Processing Record 43 of Set 2 | vila velha
# Processing Record 44 of Set 2 | arraial do cabo
# Processing Record 45 of Set 2 | axim
# Processing Record 46 of Set 2 | bebedja
# Processing Record 47 of Set 2 | port lincoln
# Processing Record 48 of Set 2 | capitan bado
# Processing Record 49 of Set 2 | lazaro cardenas
# Processing Record 0 of Set 3 | sirte
# Processing Record 1 of Set 3 | howard springs
# Processing Record 2 of Set 3 | makurazaki
# Processing Record 3 of Set 3 | shangri-la
# City not found. Skipping...
# Processing Record 4 of Set 3 | lebu
# Processing Record 5 of Set 3 | olonkinbyen
# Processing Record 6 of Set 3 | buckhannon
# Processing Record 7 of Set 3 | rzepin
# Processing Record 8 of Set 3 | tari
# Processing Record 9 of Set 3 | ouani
# Processing Record 10 of Set 3 | bandar lampung
# Processing Record 11 of Set 3 | revda
# Processing Record 12 of Set 3 | malpica
# Processing Record 13 of Set 3 | kailua-kona
# Processing Record 14 of Set 3 | talara
# Processing Record 15 of Set 3 | namibe
# Processing Record 16 of Set 3 | nantucket
# Processing Record 17 of Set 3 | urangan
# Processing Record 18 of Set 3 | copiapo
# Processing Record 19 of Set 3 | harper
# Processing Record 20 of Set 3 | booue
# Processing Record 21 of Set 3 | aasiaat
# Processing Record 22 of Set 3 | vorgashor
# Processing Record 23 of Set 3 | edinburgh of the seven seas
# Processing Record 24 of Set 3 | ust-nera
# Processing Record 25 of Set 3 | tutoia
# Processing Record 26 of Set 3 | qujing
# Processing Record 27 of Set 3 | chonchi
# Processing Record 28 of Set 3 | port-vila
# Processing Record 29 of Set 3 | khilok
# Processing Record 30 of Set 3 | kudahuvadhoo
# Processing Record 31 of Set 3 | cadale
# Processing Record 32 of Set 3 | gadzhiyevo
# Processing Record 33 of Set 3 | alpine
# Processing Record 34 of Set 3 | hamilton
# Processing Record 35 of Set 3 | n'zeto
# Processing Record 36 of Set 3 | bogale
# Processing Record 37 of Set 3 | fort st. john
# Processing Record 38 of Set 3 | gillette
# Processing Record 39 of Set 3 | mangai
# Processing Record 40 of Set 3 | vadso
# Processing Record 41 of Set 3 | bubaque
# Processing Record 42 of Set 3 | talnakh
# Processing Record 43 of Set 3 | siocon
# Processing Record 44 of Set 3 | prachatice
# Processing Record 45 of Set 3 | al ain city
# Processing Record 46 of Set 3 | badger
# Processing Record 47 of Set 3 | nguigmi
# Processing Record 48 of Set 3 | benjamin aceval
# Processing Record 49 of Set 3 | hithadhoo
# Processing Record 0 of Set 4 | kapit
# Processing Record 1 of Set 4 | afaahiti
# Processing Record 2 of Set 4 | longboat key
# Processing Record 3 of Set 4 | alliance
# Processing Record 4 of Set 4 | tazovsky
# Processing Record 5 of Set 4 | lihue
# Processing Record 6 of Set 4 | callao
# Processing Record 7 of Set 4 | reggane
# Processing Record 8 of Set 4 | new norfolk
# Processing Record 9 of Set 4 | college
# Processing Record 10 of Set 4 | dudinka
# Processing Record 11 of Set 4 | nuuk
# Processing Record 12 of Set 4 | touros
# Processing Record 13 of Set 4 | akobo
# Processing Record 14 of Set 4 | kiruna
# Processing Record 15 of Set 4 | fort mcmurray
# Processing Record 16 of Set 4 | sitia
# Processing Record 17 of Set 4 | antofagasta
# Processing Record 18 of Set 4 | lai chau
# Processing Record 19 of Set 4 | bata
# Processing Record 20 of Set 4 | villa gesell
# Processing Record 21 of Set 4 | rongelap
# Processing Record 22 of Set 4 | vingt cinq
# City not found. Skipping...
# Processing Record 23 of Set 4 | klingenstein
# City not found. Skipping...
# Processing Record 24 of Set 4 | tumpat
# Processing Record 25 of Set 4 | paita
# Processing Record 26 of Set 4 | el granada
# Processing Record 27 of Set 4 | gijang
# Processing Record 28 of Set 4 | ola
# Processing Record 29 of Set 4 | onega
# Processing Record 30 of Set 4 | akureyri
# Processing Record 31 of Set 4 | popondetta
# Processing Record 32 of Set 4 | st. john's
# Processing Record 33 of Set 4 | le vauclin
# Processing Record 34 of Set 4 | kuragino
# Processing Record 35 of Set 4 | iskateley
# Processing Record 36 of Set 4 | udachny
# Processing Record 37 of Set 4 | coyhaique
# Processing Record 38 of Set 4 | cargados carajos
# City not found. Skipping...
# Processing Record 39 of Set 4 | chenzhou
# Processing Record 40 of Set 4 | port alfred
# Processing Record 41 of Set 4 | kiunga
# Processing Record 42 of Set 4 | mendi
# Processing Record 43 of Set 4 | rio verde de mato grosso
# Processing Record 44 of Set 4 | san patricio
# Processing Record 45 of Set 4 | petauke
# Processing Record 46 of Set 4 | rutland
# Processing Record 47 of Set 4 | villa vasquez
# Processing Record 48 of Set 4 | yuzhno-kurilsk
# Processing Record 49 of Set 4 | bandar-e anzali
# Processing Record 0 of Set 5 | ulladulla
# Processing Record 1 of Set 5 | calp
# Processing Record 2 of Set 5 | mujiayingzi
# Processing Record 3 of Set 5 | hollins
# Processing Record 4 of Set 5 | whitehorse
# Processing Record 5 of Set 5 | georgetown
# Processing Record 6 of Set 5 | kone
# Processing Record 7 of Set 5 | kingston
# Processing Record 8 of Set 5 | margate
# Processing Record 9 of Set 5 | general roca
# Processing Record 10 of Set 5 | kolonia
# Processing Record 11 of Set 5 | ta`u
# Processing Record 12 of Set 5 | mil'kovo
# Processing Record 13 of Set 5 | el calafate
# Processing Record 14 of Set 5 | nadi
# Processing Record 15 of Set 5 | san pedro pochutla
# Processing Record 16 of Set 5 | saudarkrokur
# Processing Record 17 of Set 5 | hawaiian paradise park
# Processing Record 18 of Set 5 | codrington
# Processing Record 19 of Set 5 | pariaman
# Processing Record 20 of Set 5 | masons bay
# City not found. Skipping...
# Processing Record 21 of Set 5 | saldanha
# Processing Record 22 of Set 5 | swinoujscie
# Processing Record 23 of Set 5 | rundu
# Processing Record 24 of Set 5 | kenora
# Processing Record 25 of Set 5 | sullivan
# Processing Record 26 of Set 5 | al bayda'
# Processing Record 27 of Set 5 | nar'yan-mar
# Processing Record 28 of Set 5 | barra de santo antonio
# Processing Record 29 of Set 5 | port augusta
# Processing Record 30 of Set 5 | annaba
# Processing Record 31 of Set 5 | severo-yeniseyskiy
# Processing Record 32 of Set 5 | corinto
# Processing Record 33 of Set 5 | kingscliff
# Processing Record 34 of Set 5 | koping
# Processing Record 35 of Set 5 | fuvahmulah
# City not found. Skipping...
# Processing Record 36 of Set 5 | kondopoga
# Processing Record 37 of Set 5 | jawhar
# Processing Record 38 of Set 5 | planadas
# Processing Record 39 of Set 5 | khanbari
# Processing Record 40 of Set 5 | pasuquin
# Processing Record 41 of Set 5 | buriti alegre
# Processing Record 42 of Set 5 | weno
# Processing Record 43 of Set 5 | san juan de miraflores
# Processing Record 44 of Set 5 | gastouni
# Processing Record 45 of Set 5 | emkhomazi
# Processing Record 46 of Set 5 | bamboo flat
# Processing Record 47 of Set 5 | tvoroyri
# Processing Record 48 of Set 5 | hailey
# Processing Record 49 of Set 5 | bonthe
# Processing Record 0 of Set 6 | dubbo
# Processing Record 1 of Set 6 | mount isa
# Processing Record 2 of Set 6 | cockburn town
# Processing Record 3 of Set 6 | gallup
# Processing Record 4 of Set 6 | makubetsu
# Processing Record 5 of Set 6 | igarka
# Processing Record 6 of Set 6 | naracoorte
# Processing Record 7 of Set 6 | tham phannara
# Processing Record 8 of Set 6 | forbes
# Processing Record 9 of Set 6 | chachapoyas
# Processing Record 10 of Set 6 | kalianget
# Processing Record 11 of Set 6 | toamasina
# Processing Record 12 of Set 6 | belmonte
# Processing Record 13 of Set 6 | tolanaro
# Processing Record 14 of Set 6 | aykhal
# Processing Record 15 of Set 6 | dickinson
# Processing Record 16 of Set 6 | kapuskasing
# Processing Record 17 of Set 6 | alcala de los gazules
# Processing Record 18 of Set 6 | plettenberg bay
# Processing Record 19 of Set 6 | oil city
# Processing Record 20 of Set 6 | saipan
# Processing Record 21 of Set 6 | muisne
# Processing Record 22 of Set 6 | anse royale
# Processing Record 23 of Set 6 | montego bay
# Processing Record 24 of Set 6 | cabo san lucas
# Processing Record 25 of Set 6 | cam ranh
# Processing Record 26 of Set 6 | haiku-pauwela
# Processing Record 27 of Set 6 | greymouth
# Processing Record 28 of Set 6 | nadym
# Processing Record 29 of Set 6 | puerto baquerizo moreno
# Processing Record 30 of Set 6 | guerrero negro
# Processing Record 31 of Set 6 | barcelos
# Processing Record 32 of Set 6 | sinan
# Processing Record 33 of Set 6 | sidi bouzid
# Processing Record 34 of Set 6 | ji'an
# Processing Record 35 of Set 6 | kearney
# Processing Record 36 of Set 6 | bathsheba
# Processing Record 37 of Set 6 | ar ruseris
# Processing Record 38 of Set 6 | geraldton
# Processing Record 39 of Set 6 | jerez de garcia salinas
# Processing Record 40 of Set 6 | san jose del guaviare
# Processing Record 41 of Set 6 | al-`ula
# City not found. Skipping...
# Processing Record 42 of Set 6 | vredenburg
# City not found. Skipping...
# Processing Record 43 of Set 6 | yarmouth
# Processing Record 44 of Set 6 | remire-montjoly
# Processing Record 45 of Set 6 | sechura
# Processing Record 46 of Set 6 | itoman
# Processing Record 47 of Set 6 | kattivakkam
# Processing Record 48 of Set 6 | canutama
# Processing Record 49 of Set 6 | broome
# Processing Record 0 of Set 7 | papao
# Processing Record 1 of Set 7 | murun-kuren
# Processing Record 2 of Set 7 | usinsk
# Processing Record 3 of Set 7 | shira
# Processing Record 4 of Set 7 | hayma'
# City not found. Skipping...
# Processing Record 5 of Set 7 | belawan
# Processing Record 6 of Set 7 | alvaraes
# Processing Record 7 of Set 7 | acarau
# Processing Record 8 of Set 7 | vila franca do campo
# Processing Record 9 of Set 7 | nagai
# Processing Record 10 of Set 7 | pisco
# Processing Record 11 of Set 7 | christchurch
# Processing Record 12 of Set 7 | east london
# Processing Record 13 of Set 7 | tsiombe
# Processing Record 14 of Set 7 | suining
# Processing Record 15 of Set 7 | ancud
# Processing Record 16 of Set 7 | fannuj
# City not found. Skipping...
# Processing Record 17 of Set 7 | santa elena de uairen
# Processing Record 18 of Set 7 | suntar
# Processing Record 19 of Set 7 | kushnarenkovo
# Processing Record 20 of Set 7 | iwaki
# Processing Record 21 of Set 7 | acajutla
# Processing Record 22 of Set 7 | badulla
# Processing Record 23 of Set 7 | fuling
# Processing Record 24 of Set 7 | syanno
# Processing Record 25 of Set 7 | las tablas
# Processing Record 26 of Set 7 | siwa oasis
# Processing Record 27 of Set 7 | valparaiso
# Processing Record 28 of Set 7 | sault ste. marie
# Processing Record 29 of Set 7 | al kharijah
# Processing Record 30 of Set 7 | choele choel
# Processing Record 31 of Set 7 | riviere-du-loup
# Processing Record 32 of Set 7 | toga village
# City not found. Skipping...
# Processing Record 33 of Set 7 | datong
# Processing Record 34 of Set 7 | la'ie
# Processing Record 35 of Set 7 | dwarka
# Processing Record 36 of Set 7 | daokou
# Processing Record 37 of Set 7 | culebra
# Processing Record 38 of Set 7 | bengkulu
# Processing Record 39 of Set 7 | sandnessjoen
# Processing Record 40 of Set 7 | leninsk
# Processing Record 41 of Set 7 | vysokovsk
# Processing Record 42 of Set 7 | buritis
# Processing Record 43 of Set 7 | guiping
# Processing Record 44 of Set 7 | wanganui
# Processing Record 45 of Set 7 | vernon
# Processing Record 46 of Set 7 | kayangel
# Processing Record 47 of Set 7 | coeur d'alene
# Processing Record 48 of Set 7 | keren
# Processing Record 49 of Set 7 | veracruz
# Processing Record 0 of Set 8 | boyolangu
# Processing Record 1 of Set 8 | nouadhibou
# Processing Record 2 of Set 8 | petawawa
# Processing Record 3 of Set 8 | cambridge
# Processing Record 4 of Set 8 | arenapolis
# Processing Record 5 of Set 8 | pangai
# Processing Record 6 of Set 8 | acapulco de juarez
# Processing Record 7 of Set 8 | sanctuary point
# Processing Record 8 of Set 8 | lagunas
# Processing Record 9 of Set 8 | altinekin
# Processing Record 10 of Set 8 | nyurba
# Processing Record 11 of Set 8 | makarov
# Processing Record 12 of Set 8 | zhovti vody
# Processing Record 13 of Set 8 | susuman
# Processing Record 14 of Set 8 | macapa
# Processing Record 15 of Set 8 | kuala belait
# Processing Record 16 of Set 8 | tobol'sk
# Processing Record 17 of Set 8 | rockenhausen
# Processing Record 18 of Set 8 | mount gambier
# Processing Record 19 of Set 8 | clodomira
# Processing Record 20 of Set 8 | ulanhot
# Processing Record 21 of Set 8 | olyokminsk
# Processing Record 22 of Set 8 | sake
# Processing Record 23 of Set 8 | grand-bassam
# Processing Record 24 of Set 8 | ciudad bolivar
# Processing Record 25 of Set 8 | belfast
# Processing Record 26 of Set 8 | coquimbo
# Processing Record 27 of Set 8 | prince rupert
# Processing Record 28 of Set 8 | petropavlovsk-kamchatsky
# Processing Record 29 of Set 8 | ribas do rio pardo
# Processing Record 30 of Set 8 | arrifes
# Processing Record 31 of Set 8 | lompoc
# Processing Record 32 of Set 8 | iwanai
# Processing Record 33 of Set 8 | san andres
# Processing Record 34 of Set 8 | akrehamn
# Processing Record 35 of Set 8 | hirara
# Processing Record 36 of Set 8 | fort bragg
# Processing Record 37 of Set 8 | dungarvan
# Processing Record 38 of Set 8 | yemetsk
# Processing Record 39 of Set 8 | mahonda
# Processing Record 40 of Set 8 | fish town
# Processing Record 41 of Set 8 | smithers
# Processing Record 42 of Set 8 | kasongo-lunda
# Processing Record 43 of Set 8 | lebedyan'
# Processing Record 44 of Set 8 | cotonou
# Processing Record 45 of Set 8 | puerto santa
# Processing Record 46 of Set 8 | noumea
# Processing Record 47 of Set 8 | uturoa
# Processing Record 48 of Set 8 | khandyga
# Processing Record 49 of Set 8 | ahau
# City not found. Skipping...
# Processing Record 0 of Set 9 | luderitz
# Processing Record 1 of Set 9 | kapa'a
# Processing Record 2 of Set 9 | tralee
# Processing Record 3 of Set 9 | keflavik
# Processing Record 4 of Set 9 | kisangani
# Processing Record 5 of Set 9 | lamu
# Processing Record 6 of Set 9 | mizil
# Processing Record 7 of Set 9 | dubois
# Processing Record 8 of Set 9 | kavaratti
# Processing Record 9 of Set 9 | marquette
# Processing Record 10 of Set 9 | benguela
# Processing Record 11 of Set 9 | frenda
# Processing Record 12 of Set 9 | forquilhinha
# Processing Record 13 of Set 9 | pando
# Processing Record 14 of Set 9 | flying fish cove
# Processing Record 15 of Set 9 | holualoa
# Processing Record 16 of Set 9 | souillac
# Processing Record 17 of Set 9 | pandan
# Processing Record 18 of Set 9 | sangola
# Processing Record 19 of Set 9 | island harbour
# Processing Record 20 of Set 9 | magadan
# Processing Record 21 of Set 9 | san juanito
# Processing Record 22 of Set 9 | isiro
# Processing Record 23 of Set 9 | mata-utu
# Processing Record 24 of Set 9 | conde
# Processing Record 25 of Set 9 | wynyard
# Processing Record 26 of Set 9 | sisimiut
# Processing Record 27 of Set 9 | tabou
# Processing Record 28 of Set 9 | zheleznogorsk
# Processing Record 29 of Set 9 | rosetta
# Processing Record 30 of Set 9 | bayji
# Processing Record 31 of Set 9 | aswan
# Processing Record 32 of Set 9 | kunashak
# Processing Record 33 of Set 9 | gazli
# Processing Record 34 of Set 9 | santander jimenez
# Processing Record 35 of Set 9 | odenthal
# Processing Record 36 of Set 9 | tionk essil
# Processing Record 37 of Set 9 | askoy
# Processing Record 38 of Set 9 | nishinoomote
# Processing Record 39 of Set 9 | pathein
# Processing Record 40 of Set 9 | tibanbang
# Processing Record 41 of Set 9 | twentynine palms
# Processing Record 42 of Set 9 | nova sintra
# Processing Record 43 of Set 9 | lubao
# Processing Record 44 of Set 9 | tandalti
# Processing Record 45 of Set 9 | zapala
# Processing Record 46 of Set 9 | okondja
# Processing Record 47 of Set 9 | makoua
# Processing Record 48 of Set 9 | gorom-gorom
# Processing Record 49 of Set 9 | gbadolite
# Processing Record 0 of Set 10 | puerto aysen
# Processing Record 1 of Set 10 | al jawf
# Processing Record 2 of Set 10 | xilin hot
# Processing Record 3 of Set 10 | gurupi
# Processing Record 4 of Set 10 | sudak
# Processing Record 5 of Set 10 | sitka
# Processing Record 6 of Set 10 | salinopolis
# Processing Record 7 of Set 10 | chiang rai
# Processing Record 8 of Set 10 | qusmuryn
# Processing Record 9 of Set 10 | tashtyp
# Processing Record 10 of Set 10 | jalpa
# Processing Record 11 of Set 10 | qamdo
# Processing Record 12 of Set 10 | kuta
# Processing Record 13 of Set 10 | sola
# Processing Record 14 of Set 10 | elmendorf air force base
# City not found. Skipping...
# Processing Record 15 of Set 10 | qorovulbozor
# Processing Record 16 of Set 10 | bealanana
# Processing Record 17 of Set 10 | verdal
# Processing Record 18 of Set 10 | diamantino
# Processing Record 19 of Set 10 | thongwa
# Processing Record 20 of Set 10 | nizhniy odes
# Processing Record 21 of Set 10 | mugia
# Processing Record 22 of Set 10 | pachino
# Processing Record 23 of Set 10 | vanino
# Processing Record 24 of Set 10 | mpika
# Processing Record 25 of Set 10 | gorzyce
# Processing Record 26 of Set 10 | la tuque
# Processing Record 27 of Set 10 | uitenhage
# Processing Record 28 of Set 10 | gorontalo
# Processing Record 29 of Set 10 | sao joao da barra
# Processing Record 30 of Set 10 | banjarmasin
# Processing Record 31 of Set 10 | polyarnyy
# Processing Record 32 of Set 10 | alotau
# Processing Record 33 of Set 10 | saint-philippe
# Processing Record 34 of Set 10 | port macquarie
# Processing Record 35 of Set 10 | bizerte
# Processing Record 36 of Set 10 | massakory
# Processing Record 37 of Set 10 | taro
# Processing Record 38 of Set 10 | dipayal
# Processing Record 39 of Set 10 | ugep
# Processing Record 40 of Set 10 | oskarshamn
# Processing Record 41 of Set 10 | suva
# Processing Record 42 of Set 10 | jayapura
# Processing Record 43 of Set 10 | sao vicente
# Processing Record 44 of Set 10 | hihifo
# City not found. Skipping...
# Processing Record 45 of Set 10 | ormara
# Processing Record 46 of Set 10 | anse a galets
# Processing Record 47 of Set 10 | nakhon si thammarat
# Processing Record 48 of Set 10 | muynoq
# Processing Record 49 of Set 10 | amga
# Processing Record 0 of Set 11 | al muwayh
# Processing Record 1 of Set 11 | talakan
# Processing Record 2 of Set 11 | lucapa
# Processing Record 3 of Set 11 | rancho palos verdes
# Processing Record 4 of Set 11 | alvorada
# Processing Record 5 of Set 11 | jijel
# Processing Record 6 of Set 11 | north bend
# Processing Record 7 of Set 11 | zag
# Processing Record 8 of Set 11 | ouidah
# Processing Record 9 of Set 11 | pokaran
# Processing Record 10 of Set 11 | kapoeta
# Processing Record 11 of Set 11 | colonia
# Processing Record 12 of Set 11 | santo antonio do ica
# Processing Record 13 of Set 11 | mandimba
# Processing Record 14 of Set 11 | tosontsengel
# Processing Record 15 of Set 11 | matoury
# Processing Record 16 of Set 11 | molo
# Processing Record 17 of Set 11 | kulia village
# City not found. Skipping...
# Processing Record 18 of Set 11 | newman
# Processing Record 19 of Set 11 | oumache
# Processing Record 20 of Set 11 | kirensk
# Processing Record 21 of Set 11 | monahans
# Processing Record 22 of Set 11 | cabedelo
# Processing Record 23 of Set 11 | gamba
# Processing Record 24 of Set 11 | kingsville
# Processing Record 25 of Set 11 | hammerfest
# Processing Record 26 of Set 11 | kheralu
# Processing Record 27 of Set 11 | zhanaozen
# Processing Record 28 of Set 11 | katima mulilo
# Processing Record 29 of Set 11 | selfoss
# Processing Record 30 of Set 11 | paoy paet
# Processing Record 31 of Set 11 | luganville
# Processing Record 32 of Set 11 | kulhudhuffushi
# Processing Record 33 of Set 11 | gizo
# Processing Record 34 of Set 11 | santa marta de ortigueira
# Processing Record 35 of Set 11 | nyrob
# Processing Record 36 of Set 11 | sao desiderio
# Processing Record 37 of Set 11 | champerico
# Processing Record 38 of Set 11 | dongola
# Processing Record 39 of Set 11 | brigantine
# Processing Record 40 of Set 11 | sterling
# Processing Record 41 of Set 11 | shwebo
# Processing Record 42 of Set 11 | taroa
# Processing Record 43 of Set 11 | kruisfontein
# Processing Record 44 of Set 11 | ad dawadimi
# Processing Record 45 of Set 11 | as sulayyil
# Processing Record 46 of Set 11 | qusar
# Processing Record 47 of Set 11 | gazojak
# Processing Record 48 of Set 11 | alaghsas
# Processing Record 49 of Set 11 | macusani
# Processing Record 0 of Set 12 | al bardiyah
# Processing Record 1 of Set 12 | al hazm
# Processing Record 2 of Set 12 | boca suno
# Processing Record 3 of Set 12 | i-n-salah
# Processing Record 4 of Set 12 | ha giang
# Processing Record 5 of Set 12 | nacala
# Processing Record 6 of Set 12 | antsiranana
# Processing Record 7 of Set 12 | tyukhtet
# Processing Record 8 of Set 12 | zabaykal'sk
# Processing Record 9 of Set 12 | am timan
# Processing Record 10 of Set 12 | inirida
# Processing Record 11 of Set 12 | barranca
# Processing Record 12 of Set 12 | puget-sur-argens
# Processing Record 13 of Set 12 | lityn
# Processing Record 14 of Set 12 | ginir
# Processing Record 15 of Set 12 | okhotsk
# Processing Record 16 of Set 12 | pskov
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          547
# Lat           547
# Lng           547
# Max Temp      547
# Humidity      547
# Cloudiness    547
# Wind Speed    547
# Country       547
# Date          547
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           buala  -8.1450  159.5921     29.56        70          89
# 1      choibalsan  48.0667  114.5000    -21.69        83          53
# 2   blackmans bay -43.0167  147.3167     24.85        66          12
# 3  ribeira grande  38.5167  -28.7000     18.21        95         100
# 4           kimbe  -5.5502  150.1429     31.28        63         100
#
#    Wind Speed Country        Date
# 0        4.52      SB  1738539570
# 1        3.40      MN  1738539571
# 2        3.41      AU  1738539572
# 3        9.39      PT  1738539573
# 4        1.81      PG  1738539574

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                 buala  -8.1450  159.5921     29.56        70          89
# 1            choibalsan  48.0667  114.5000    -21.69        83          53
# 2         blackmans bay -43.0167  147.3167     24.85        66          12
# 3        ribeira grande  38.5167  -28.7000     18.21        95         100
# 4                 kimbe  -5.5502  150.1429     31.28        63         100
#
#          Wind Speed Country        Date
# City_ID
# 0              4.52      SB  1738539570
# 1              3.40      MN  1738539571
# 2              3.41      AU  1738539572
# 3              9.39      PT  1738539573
# 4              1.81      PG  1738539574

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"],city_data_df["Max Temp"], marker="o")

# Incorporate the other graph properties
plt.title("City Max Latitude vs. Temperature (2025-02-01)")
plt.ylabel("Max Temperature (C)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"],city_data_df["Humidity"], marker="o")

# Incorporate the other graph properties
plt.title("City Max Latitude vs. Humidity (2025-02-01)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"],city_data_df["Cloudiness"], marker="o")

# Incorporate the other graph properties
plt.title("City Max Latitude vs. Cloudiness (2025-02-01)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"],city_data_df["Wind Speed"], marker="o")

# Incorporate the other graph properties
plt.title("City Max Latitude vs. Wind Speed (2025-02-01)")
plt.ylabel("Wind Speed (m/s)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df["Lat"]>=0]

# Display sample data
northern_hemi_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1            choibalsan  48.0667  114.5000    -21.69        83          53
# 3        ribeira grande  38.5167  -28.7000     18.21        95         100
# 7              qaqortoq  60.7167  -46.0333    -20.51        92          10
# 8              jianshui  23.6363  102.8264      8.73        93          69
# 9            isafjordur  66.0755  -23.1240     -3.23        79          84
#
#          Wind Speed Country        Date
# City_ID
# 1              3.40      MN  1738539571
# 3              9.39      PT  1738539573
# 7              2.07      GL  1738539577
# 8              3.12      CN  1738539578
# 9              2.78      IS  1738539580

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df["Lat"]<=0]

# Display sample data
southern_hemi_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                buala  -8.1450  159.5921     29.56        70          89
# 2        blackmans bay -43.0167  147.3167     24.85        66          12
# 4                kimbe  -5.5502  150.1429     31.28        63         100
# 5            adamstown -25.0660 -130.1015     25.34        71          64
# 6            carnarvon -24.8667  113.6333     29.72        44          12
#
#          Wind Speed Country        Date
# City_ID
# 0              4.52      SB  1738539570
# 2              3.41      AU  1738539572
# 4              1.81      PG  1738539574
# 5              8.01      PN  1738539575
# 6             11.52      AU  1738539576

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-") 

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.annotate(line_eq,(20,15),fontsize=15,color="red",)
plt.title(f"Latitude vs Max Temp")

# Print r^2 value
print(f"The r^2-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# y = -0.75x +32.93
# The r^2-value is: 0.7207453997160479

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-") 

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.annotate(line_eq,(-20,15),fontsize=15,color="red",)
plt.title(f"Latitude vs Max Temp")

# Print r^2 value
print(f"The r^2-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# y = 0.16x +26.76
# The r^2-value is: 0.14362007831281523

# %% [markdown]
# **Discussion about the linear relationship:**
#
# We can tell from the two scatter plots and the correlation coefficient for both the northern and southern hemisphere that the further you are away from the equator, the colder it is. The temperature continues to drop the further the latitude gets away from 0.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-") 

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.annotate(line_eq,(20,15),fontsize=15,color="red",)
plt.title(f"Latitude vs Humidity")

# Print r^2 value
print(f"The r^2-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# y = 0.34x +61.91
# The r^2-value is: 0.10441843516737334

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-") 

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.annotate(line_eq,(-20,40),fontsize=15,color="red",)
plt.title(f"Latitude vs Humidity")

# Print r^2 value
print(f"The r^2-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# y = 0.55x +87.34
# The r^2-value is: 0.19473206423206343

# %% [markdown]
# **Discussion about the linear relationship:**
#
# From the comparison between latitude and humidity we can see that the further north you get, the more humid it gets. The southern hemisphere linear regression line shows humidity going up the closer you get to the equator, but the northern hemisphere linear regression shows the humidity going up the further you get from the equator.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-") 

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.annotate(line_eq,(20,15),fontsize=15,color="red",)
plt.title(f"Latitude vs Cloudiness")

# Print r^2 value
print(f"The r^2-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# y = 0.37x +43.17
# The r^2-value is: 0.036451271693236253

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-") 

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.annotate(line_eq,(-20,15),fontsize=15,color="red",)
plt.title(f"Latitude vs Cloudiness")

# Print r^2 value
print(f"The r^2-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# y = 0.94x +79.07
# The r^2-value is: 0.1215720303790543

# %% [markdown]
# **Discussion about the linear relationship:**
#
# There appears to be a strong correlation between cloudiness and latitude in the southern hemisphere where it gets cloudier the closer you get to the equator. However, in the northern hemisphere there is less of a correlation and there seems to be more of a grouping of eaither very cloudy places and places that are not cloudy at all across all distances from the equatoer.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-") 

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.annotate(line_eq,(20,15),fontsize=15,color="red",)
plt.title(f"Latitude vs Wind Speed")

# Print r^2 value
print(f"The r^2-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# y = 0.0x +3.57
# The r^2-value is: 0.00024142951873596852

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-") 

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.annotate(line_eq,(-20,15),fontsize=15,color="red",)
plt.title(f"Latitude vs Wind Speed")

# Print r^2 value
print(f"The r^2-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# y = -0.08x +2.41
# The r^2-value is: 0.14060173824218092

# %% [markdown]
# **Discussion about the linear relationship:**
#
# Wind speed does not seem to have much correlation to latitude. We can see the linear regression line for the northern hemisphere is almost flat. For the southern hemispher, there seems to be a slight correlation but the cities still all seemed to be grouped together under 10.
